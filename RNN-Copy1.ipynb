# %%
# First lets improve libraries that we are going to be used in this lab session
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from collections import Counter
import pickle as pkl
import random
import pdb
random.seed(134)
import pandas as pd
PAD_IDX = 0
UNK_IDX = 1
BATCH_SIZE = 32

# %%
import pickle as pkl
tt_sen1 = pkl.load(open("tt_sen1.p", "rb"))
tt_sen2 = pkl.load(open("tt_sen2.p", "rb"))
tv_sen1 = pkl.load(open("tv_sen1.p", "rb"))
tv_sen2 = pkl.load(open("tv_sen2.p", "rb"))
train_targets = pkl.load(open("train_targets.p", "rb"))
val_targets = pkl.load(open("val_targets.p", "rb"))

# %%
words_to_load = 50000

import numpy as np

with open('wiki-news-300d-1M.vec') as f:
    loaded_embeddings_ft = np.zeros((words_to_load, 300))
    words_ft = {}
    idx2words_ft = {}
    ordered_words_ft = []
    for i, line in enumerate(f):
        if i >= words_to_load: 
            break
        s = line.split()
        loaded_embeddings_ft[i, :] = np.asarray(s[1:])
        words_ft[s[0]] = i
        idx2words_ft[i] = s[0]
        ordered_words_ft.append(s[0])

# %%
#id2token
x=idx2words_ft
#token2idx
y=words_ft

# %%
idx2words_ft={}
idx2words_ft[0]='<pad>'
idx2words_ft[1]='<unk>'
for i in range(0,50000):
    idx2words_ft[i+2]=x[i]

# %%
w=list(words_ft.keys())
words_ft={}
words_ft['<pad>']=0
words_ft['<unk>']=1
for i in range(0,50000):
    words_ft[w[i]]=i+2

# %%
z=loaded_embeddings_ft

# %%
loaded_embeddings_ft=np.zeros(300)

# %%
loaded_embeddings_ft=np.vstack([loaded_embeddings_ft,np.ones(300)])

# %%
loaded_embeddings_ft=np.vstack([loaded_embeddings_ft,z])

# %%
token2id=words_ft

# %%
id2token=list(idx2words_ft.values())

# %%
# convert token to id in the dataset
def token2index_dataset(tokens_data):  #REplaces each token with respective index
    indices_data = []
    for tokens in tokens_data:
        index_list = [token2id[token] if token in token2id else UNK_IDX for token in tokens]
        indices_data.append(index_list)
    return indices_data

train_data_indices1 = token2index_dataset(tt_sen1)
train_data_indices2 = token2index_dataset(tt_sen2)
val_data_indices1 = token2index_dataset(tv_sen1)
val_data_indices2 = token2index_dataset(tv_sen2)

# double checking
print ("Train dataset size is {}".format(len(train_data_indices1)))
print ("Train dataset size is {}".format(len(train_data_indices2)))
print ("Val dataset size is {}".format(len(val_data_indices1)))
print ("Val dataset size is {}".format(len(val_data_indices2)))
# Out:
# Train dataset size is 100000
# Train dataset size is 100000
# Val dataset size is 1000
# Val dataset size is 1000

# %%
mm=0
for i in range(0,100000):
    r=max(len(train_data_indices1[i]),len(train_data_indices2[i]))
    if mm<r:
        mm=r

# %%
mm
# Out:
# 82

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class NewsGroupDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """    
    def __init__(self, data_list1,data_list2, target_list):
        """
        @param data_list: list of newsgroup tokens 
        @param target_list: list of newsgroup targets 

        """
        self.data_list1 = data_list1
        self.data_list2 = data_list2
        self.target_list = target_list
        assert (len(self.data_list1) == len(self.target_list))
        assert (len(self.data_list2) == len(self.target_list))
        assert (len(self.data_list1) == len(self.data_list2))
    def __len__(self):
        assert (len(self.data_list1) == len(self.data_list2))
        return len(self.data_list1)
        
    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        token_idx1 = self.data_list1[key][:MAX_SENTENCE_LENGTH]       
        token_idx2 = self.data_list2[key][:MAX_SENTENCE_LENGTH]
        label = self.target_list[key]
        return [token_idx1, len(token_idx1),token_idx2, len(token_idx2), label]

# %%
MAX_SENTENCE_LENGTH = mm
#MAX_SENTENCE_LENGTH is a hyperparameter
#We implement dataset first before data loader. It takes 2 things as input.
#Datatlist (dataset converted to indices of tokens)
#Targetlist ( number between 1-20 that represents the target of document)
#We need to implement len and getitem

import numpy as np
import torch
from torch.utils.data import Dataset

class NewsGroupDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """    
    def __init__(self, data_list1,data_list2, target_list):
        """
        @param data_list: list of newsgroup tokens 
        @param target_list: list of newsgroup targets 

        """
        self.data_list1 = data_list1
        self.data_list2 = data_list2
        self.target_list = target_list
        assert (len(self.data_list1) == len(self.target_list))
        assert (len(self.data_list2) == len(self.target_list))
        assert (len(self.data_list1) == len(self.data_list2))
    def __len__(self):
        assert (len(self.data_list1) == len(self.data_list2))
        return len(self.data_list1)
        
    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        token_idx1 = self.data_list1[key][:MAX_SENTENCE_LENGTH]       
        token_idx2 = self.data_list2[key][:MAX_SENTENCE_LENGTH]
        label = self.target_list[key]
        return [token_idx1, len(token_idx1),token_idx2, len(token_idx2), label]
#Collate function adds padding symbols to data in case its smaller than
# the max sentence length
def newsgroup_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all 
    data have the same length
    """
    data_list1 = []
    length_list1 = []
    data_list2 = []
    length_list2 = []
    label_list = []

    #print("collate batch: ", batch[0][0])
    #batch[0][0] = batch[0][0][:MAX_SENTENCE_LENGTH]
    for datum in batch:
        label_list.append(datum[4])
        length_list1.append(datum[1])
        length_list2.append(datum[3])
    # padding
    for datum in batch:
        padded_vec1 = np.pad(np.array(datum[0]), 
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[1])), 
                                mode="constant", constant_values=0)
        data_list1.append(padded_vec1)
        padded_vec2 = np.pad(np.array(datum[2]), 
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[3])), 
                                mode="constant", constant_values=0)
        data_list2.append(padded_vec2)
        
    ind_dec_order1 = np.argsort(length_list1)[::-1]
    ind_dec_order2 = np.argsort(length_list2)[::-1]
    
    data_list1 = np.array(data_list1)[ind_dec_order1]
    data_list2 = np.array(data_list2)[ind_dec_order2]
    
    length_list1 = np.array(length_list1)[ind_dec_order1]
    length_list2 = np.array(length_list2)[ind_dec_order2]
    
#     label_list = np.array(label_list)[ind_dec_order]    
        
    return [torch.from_numpy(np.array(data_list1)), torch.from_numpy(np.array(np.int32(length_list1))) ,torch.from_numpy(np.array(data_list2)), torch.from_numpy(np.array(np.int32(length_list2))), torch.from_numpy(np.array(np.int32(label_list))).long(),ind_dec_order1,ind_dec_order2]

# create pytorch dataloader
#train_loader = NewsGroupDataset(train_data_indices, train_targets)
#val_loader = NewsGroupDataset(val_data_indices, val_targets)
#test_loader = NewsGroupDataset(test_data_indices, test_targets)
#train_dataset is a hyperparameter and also batchsize
#train and validation also has shuffling here
BATCH_SIZE = 32
train_dataset = NewsGroupDataset(train_data_indices1, train_data_indices2, train_targets)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=newsgroup_collate_func,
                                           shuffle=True)


val_dataset = NewsGroupDataset(val_data_indices1, val_data_indices2, val_targets)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                           batch_size=BATCH_SIZE,
                                           collate_fn=newsgroup_collate_func,
                                           shuffle=True)


#for i, (data, lengths, labels) in enumerate(train_loader):
#    print (data)
#    print (labels)
#    break

# %% [markdown]
# ### Now lets implement basic Convolutional Neural Net model for text

# %%
weight = torch.FloatTensor(loaded_embeddings_ft)

# %%
class RNN(nn.Module):
    def __init__(self, emb_size, hidden_size, num_layers, num_classes, vocab_size):
        # RNN Accepts the following hyperparams:
        # emb_size: Embedding Size
        # hidden_size: Hidden Size of layer in RNN
        # num_layers: number of layers in RNN
        # num_classes: number of output classes
        # vocab_size: vocabulary size
        super(RNN, self).__init__()

        self.num_layers, self.hidden_size = num_layers, hidden_size
        self.embedding = nn.Embedding.from_pretrained(weight,freeze=True)
        self.rnn = nn.RNN(emb_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(2*hidden_size, num_classes)

    def init_hidden(self, batch_size):
        # Function initializes the activation of recurrent neural net at timestep 0
        # Needs to be in format (num_layers, batch_size, hidden_size)
        hidden = torch.randn(self.num_layers, batch_size, self.hidden_size)
        return hidden

    def forward(self, x1, lengths1, x2, lengths2,id1,id2):
        # reset hidden state

        batch_size1, seq_len1 = x1.size()
        batch_size2, seq_len2 = x2.size()
        
        self.hidden1 = self.init_hidden(batch_size1)
        self.hidden2 = self.init_hidden(batch_size2)
        # get embedding of characters
        embed1 = self.embedding(x1)
        embed2 = self.embedding(x2)
        # pack padded sequence
        #Pytorch wants sequences to be in descending order. First one have longest length and
        #Then the subsequent ones have lesser lengths
        embed1 = torch.nn.utils.rnn.pack_padded_sequence(embed1, lengths1.numpy(), batch_first=True)
        embed2 = torch.nn.utils.rnn.pack_padded_sequence(embed2, lengths2.numpy(), batch_first=True)
        
        # fprop though RNN
        rnn_out1, self.hidden1 = self.rnn(embed1, self.hidden1)
        rnn_out2, self.hidden2 = self.rnn(embed2, self.hidden2)
        
        # undo packing
        rnn_out1, _ = torch.nn.utils.rnn.pad_packed_sequence(rnn_out1, batch_first=True)
        rnn_out2, _ = torch.nn.utils.rnn.pad_packed_sequence(rnn_out2, batch_first=True)

        # sum hidden activations of RNN across time
        rnn_out1 = torch.sum(rnn_out1, dim=1)
        rnn_out2 = torch.sum(rnn_out2, dim=1)
        

        r1=rnn_out1.clone()
        r2=rnn_out2.clone()
        for i in range(0,len(r1)):
            rnn_out1[i]=r1[id1[i]]
        for i in range(0,len(r2)):
            rnn_out2[i]=r2[id2[i]]
        rnnoutfinal = torch.cat((rnn_out1, rnn_out2), 1)

        logits = self.linear(rnnoutfinal)
        return logits

# %%
pl=[]
pa=[]
epl=[]
epa=[]
llist=[]
def test_model(loader, model):
    """
    Help function that tests the model's performance on a dataset
    @param: loader - data loader for the dataset to test against
    """
    correct = 0
    total = 0
    model.eval()
    for data1, lengths1,data2, lengths2, labels,id1,id2 in loader:
        data_batch1, lengths_batch1,data_batch2, lengths_batch2, label_batch,idd1,idd2 = data1, lengths1,data2, lengths2, labels,id1,id2
        outputs = F.softmax(model(data_batch1, lengths_batch1,data_batch2, lengths_batch2,idd1,idd2), dim=1)
        predicted = outputs.max(1, keepdim=True)[1]

        total += labels.size(0)
        correct += predicted.eq(labels.view_as(predicted)).sum().item()
        llist.append([data1,data2,labels,predicted])
    return (100 * correct / total)


model = RNN(emb_size=300, hidden_size=300, num_layers=2, num_classes=3, vocab_size=50002)

learning_rate = 3e-4
num_epochs = 10 # number epoch to train

# Criterion and Optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)

for epoch in range(num_epochs):
    l=0
    a=0
    c=0
    for i, (data1, lengths1,data2, lengths2, labels,id1,id2) in enumerate(train_loader):
        model.train()
        optimizer.zero_grad()
        # Forward pass
        outputs = model(data1, lengths1,data2, lengths2,id1,id2)
        loss = criterion(outputs, labels)

        # Backward and optimize
        loss.backward()
        optimizer.step()
        # validate every 100 iterations
        if i > 0 and i % 100 == 0:
            # validate
            
            val_acc = test_model(val_loader, model)
            c=c+1
            l=l+loss.item()
            a=a+val_acc
            print('Epoch: [{}/{}], Step: [{}/{}], Validation Acc: {}'.format(
                       epoch+1, num_epochs, i+1, len(train_loader), val_acc))
            pa.append(val_acc)
            pl.append(loss.item())
    epl.append(l/c)
    epa.append(a/c)
# Out:
# Epoch: [1/10], Step: [101/3125], Validation Acc: 53.3
# Epoch: [1/10], Step: [201/3125], Validation Acc: 52.7
# Epoch: [1/10], Step: [301/3125], Validation Acc: 55.5
# Epoch: [1/10], Step: [401/3125], Validation Acc: 51.9
# Epoch: [1/10], Step: [501/3125], Validation Acc: 52.5
# Epoch: [1/10], Step: [601/3125], Validation Acc: 52.4
# Epoch: [1/10], Step: [701/3125], Validation Acc: 56.6
# Epoch: [1/10], Step: [801/3125], Validation Acc: 53.8
# Epoch: [1/10], Step: [901/3125], Validation Acc: 53.9
# Epoch: [1/10], Step: [1001/3125], Validation Acc: 54.7
# Epoch: [1/10], Step: [1101/3125], Validation Acc: 51.6
# Epoch: [1/10], Step: [1201/3125], Validation Acc: 54.2
# Epoch: [1/10], Step: [1301/3125], Validation Acc: 52.5
# Epoch: [1/10], Step: [1401/3125], Validation Acc: 52.8
# Epoch: [1/10], Step: [1501/3125], Validation Acc: 53.5
# Epoch: [1/10], Step: [1601/3125], Validation Acc: 54.9
# Epoch: [1/10], Step: [1701/3125], Validation Acc: 56.1
# Epoch: [1/10], Step: [1801/3125], Validation Acc: 52.1
# Epoch: [1/10], Step: [1901/3125], Validation Acc: 54.4
# Epoch: [1/10], Step: [2001/3125], Validation Acc: 55.1
# Epoch: [1/10], Step: [2101/3125], Validation Acc: 54.2
# Epoch: [1/10], Step: [2201/3125], Validation Acc: 53.6
# Epoch: [1/10], Step: [2301/3125], Validation Acc: 54.3
# Epoch: [1/10], Step: [2401/3125], Validation Acc: 54.0
# Epoch: [1/10], Step: [2501/3125], Validation Acc: 52.3
# Epoch: [1/10], Step: [2601/3125], Validation Acc: 52.9
# Epoch: [1/10], Step: [2701/3125], Validation Acc: 51.8
# Epoch: [1/10], Step: [2801/3125], Validation Acc: 51.8
# Epoch: [1/10], Step: [2901/3125], Validation Acc: 53.6
# Epoch: [1/10], Step: [3001/3125], Validation Acc: 54.1
# Epoch: [1/10], Step: [3101/3125], Validation Acc: 54.7
# Epoch: [2/10], Step: [101/3125], Validation Acc: 53.4
# Epoch: [2/10], Step: [201/3125], Validation Acc: 53.8
# Epoch: [2/10], Step: [301/3125], Validation Acc: 51.7
# Epoch: [2/10], Step: [401/3125], Validation Acc: 54.3
# Epoch: [2/10], Step: [501/3125], Validation Acc: 53.8
# Epoch: [2/10], Step: [601/3125], Validation Acc: 54.6
# Epoch: [2/10], Step: [701/3125], Validation Acc: 54.5
# Epoch: [2/10], Step: [801/3125], Validation Acc: 53.7
# Epoch: [2/10], Step: [901/3125], Validation Acc: 52.7
# Epoch: [2/10], Step: [1001/3125], Validation Acc: 53.4
# Epoch: [2/10], Step: [1101/3125], Validation Acc: 52.6
# Epoch: [2/10], Step: [1201/3125], Validation Acc: 52.7
# Epoch: [2/10], Step: [1301/3125], Validation Acc: 52.8
# Epoch: [2/10], Step: [1401/3125], Validation Acc: 53.6
# Epoch: [2/10], Step: [1501/3125], Validation Acc: 53.6
# Epoch: [2/10], Step: [1601/3125], Validation Acc: 54.9
# Epoch: [2/10], Step: [1701/3125], Validation Acc: 53.5
# Epoch: [2/10], Step: [1801/3125], Validation Acc: 53.6
# Epoch: [2/10], Step: [1901/3125], Validation Acc: 52.2
# Epoch: [2/10], Step: [2001/3125], Validation Acc: 52.0
# Epoch: [2/10], Step: [2101/3125], Validation Acc: 53.2
# Epoch: [2/10], Step: [2201/3125], Validation Acc: 55.9
# Epoch: [2/10], Step: [2301/3125], Validation Acc: 54.8
# Epoch: [2/10], Step: [2401/3125], Validation Acc: 55.3
# Epoch: [2/10], Step: [2501/3125], Validation Acc: 51.5
# Epoch: [2/10], Step: [2601/3125], Validation Acc: 54.8
# Epoch: [2/10], Step: [2701/3125], Validation Acc: 52.7
# Epoch: [2/10], Step: [2801/3125], Validation Acc: 51.2
# Epoch: [2/10], Step: [2901/3125], Validation Acc: 54.0
# Epoch: [2/10], Step: [3001/3125], Validation Acc: 55.2
# Epoch: [2/10], Step: [3101/3125], Validation Acc: 54.6
# Epoch: [3/10], Step: [101/3125], Validation Acc: 52.4
# Epoch: [3/10], Step: [201/3125], Validation Acc: 56.2
# Epoch: [3/10], Step: [301/3125], Validation Acc: 51.5
# Epoch: [3/10], Step: [401/3125], Validation Acc: 53.7
# Epoch: [3/10], Step: [501/3125], Validation Acc: 51.9
# Epoch: [3/10], Step: [601/3125], Validation Acc: 55.1
# Epoch: [3/10], Step: [701/3125], Validation Acc: 54.3
# Epoch: [3/10], Step: [801/3125], Validation Acc: 51.2
# Epoch: [3/10], Step: [901/3125], Validation Acc: 55.3
# Epoch: [3/10], Step: [1001/3125], Validation Acc: 52.0
# Epoch: [3/10], Step: [1101/3125], Validation Acc: 53.2
# Epoch: [3/10], Step: [1201/3125], Validation Acc: 55.0
# Epoch: [3/10], Step: [1301/3125], Validation Acc: 54.1
# Epoch: [3/10], Step: [1401/3125], Validation Acc: 52.5
# Epoch: [3/10], Step: [1501/3125], Validation Acc: 53.2
# Epoch: [3/10], Step: [1601/3125], Validation Acc: 53.4
# Epoch: [3/10], Step: [1701/3125], Validation Acc: 54.5
# Epoch: [3/10], Step: [1801/3125], Validation Acc: 54.6
# Epoch: [3/10], Step: [1901/3125], Validation Acc: 51.0
# Epoch: [3/10], Step: [2001/3125], Validation Acc: 52.8
# Epoch: [3/10], Step: [2101/3125], Validation Acc: 51.4
# Epoch: [3/10], Step: [2201/3125], Validation Acc: 53.7
# Epoch: [3/10], Step: [2301/3125], Validation Acc: 51.3
# Epoch: [3/10], Step: [2401/3125], Validation Acc: 54.5
# Epoch: [3/10], Step: [2501/3125], Validation Acc: 54.3
# Epoch: [3/10], Step: [2601/3125], Validation Acc: 53.7
# Epoch: [3/10], Step: [2701/3125], Validation Acc: 54.9
# Epoch: [3/10], Step: [2801/3125], Validation Acc: 54.1
# Epoch: [3/10], Step: [2901/3125], Validation Acc: 54.4
# Epoch: [3/10], Step: [3001/3125], Validation Acc: 51.5
# Epoch: [3/10], Step: [3101/3125], Validation Acc: 51.2
# Epoch: [4/10], Step: [101/3125], Validation Acc: 53.4
# Epoch: [4/10], Step: [201/3125], Validation Acc: 54.9
# Epoch: [4/10], Step: [301/3125], Validation Acc: 50.8
# Epoch: [4/10], Step: [401/3125], Validation Acc: 52.7
# Epoch: [4/10], Step: [501/3125], Validation Acc: 55.7
# Epoch: [4/10], Step: [601/3125], Validation Acc: 55.1
# Epoch: [4/10], Step: [701/3125], Validation Acc: 51.4
# Epoch: [4/10], Step: [801/3125], Validation Acc: 52.5
# Epoch: [4/10], Step: [901/3125], Validation Acc: 50.0
# Epoch: [4/10], Step: [1001/3125], Validation Acc: 54.1
# Epoch: [4/10], Step: [1101/3125], Validation Acc: 53.5
# Epoch: [4/10], Step: [1201/3125], Validation Acc: 53.1
# Epoch: [4/10], Step: [1301/3125], Validation Acc: 54.1
# Epoch: [4/10], Step: [1401/3125], Validation Acc: 55.2
# Epoch: [4/10], Step: [1501/3125], Validation Acc: 53.5
# Epoch: [4/10], Step: [1601/3125], Validation Acc: 54.3
# Epoch: [4/10], Step: [1701/3125], Validation Acc: 52.4
# Epoch: [4/10], Step: [1801/3125], Validation Acc: 51.2
# Epoch: [4/10], Step: [1901/3125], Validation Acc: 53.2
# Epoch: [4/10], Step: [2001/3125], Validation Acc: 53.1
# Epoch: [4/10], Step: [2101/3125], Validation Acc: 52.6
# Epoch: [4/10], Step: [2201/3125], Validation Acc: 50.8
# Epoch: [4/10], Step: [2301/3125], Validation Acc: 56.5
# Epoch: [4/10], Step: [2401/3125], Validation Acc: 54.6
# Epoch: [4/10], Step: [2501/3125], Validation Acc: 53.6
# Epoch: [4/10], Step: [2601/3125], Validation Acc: 54.2
# Epoch: [4/10], Step: [2701/3125], Validation Acc: 53.7
# Epoch: [4/10], Step: [2801/3125], Validation Acc: 51.9
# Epoch: [4/10], Step: [2901/3125], Validation Acc: 53.8
# Epoch: [4/10], Step: [3001/3125], Validation Acc: 54.0
# Epoch: [4/10], Step: [3101/3125], Validation Acc: 52.7
# Epoch: [5/10], Step: [101/3125], Validation Acc: 54.5
# Epoch: [5/10], Step: [201/3125], Validation Acc: 53.9
# Epoch: [5/10], Step: [301/3125], Validation Acc: 53.2
# Epoch: [5/10], Step: [401/3125], Validation Acc: 54.0
# Epoch: [5/10], Step: [501/3125], Validation Acc: 51.7
# Epoch: [5/10], Step: [601/3125], Validation Acc: 53.9
# Epoch: [5/10], Step: [701/3125], Validation Acc: 53.1
# Epoch: [5/10], Step: [801/3125], Validation Acc: 57.7
# Epoch: [5/10], Step: [901/3125], Validation Acc: 53.0
# Epoch: [5/10], Step: [1001/3125], Validation Acc: 51.9
# Epoch: [5/10], Step: [1101/3125], Validation Acc: 53.1
# Epoch: [5/10], Step: [1201/3125], Validation Acc: 51.4
# Epoch: [5/10], Step: [1301/3125], Validation Acc: 52.7
# Epoch: [5/10], Step: [1401/3125], Validation Acc: 52.6
# Epoch: [5/10], Step: [1501/3125], Validation Acc: 53.1
# Epoch: [5/10], Step: [1601/3125], Validation Acc: 54.1
# Epoch: [5/10], Step: [1701/3125], Validation Acc: 53.4
# Epoch: [5/10], Step: [1801/3125], Validation Acc: 53.1
# Epoch: [5/10], Step: [1901/3125], Validation Acc: 53.6
# Epoch: [5/10], Step: [2001/3125], Validation Acc: 54.2
# Epoch: [5/10], Step: [2101/3125], Validation Acc: 55.6
# Epoch: [5/10], Step: [2201/3125], Validation Acc: 52.0
# Epoch: [5/10], Step: [2301/3125], Validation Acc: 51.3
# Epoch: [5/10], Step: [2401/3125], Validation Acc: 53.1
# Epoch: [5/10], Step: [2501/3125], Validation Acc: 51.8
# Epoch: [5/10], Step: [2601/3125], Validation Acc: 52.0
# Epoch: [5/10], Step: [2701/3125], Validation Acc: 52.0
# Epoch: [5/10], Step: [2801/3125], Validation Acc: 52.1
# Epoch: [5/10], Step: [2901/3125], Validation Acc: 53.2
# Epoch: [5/10], Step: [3001/3125], Validation Acc: 55.0
# Epoch: [5/10], Step: [3101/3125], Validation Acc: 53.2
# Epoch: [6/10], Step: [101/3125], Validation Acc: 53.7
# Epoch: [6/10], Step: [201/3125], Validation Acc: 52.6
# Epoch: [6/10], Step: [301/3125], Validation Acc: 52.2
# Epoch: [6/10], Step: [401/3125], Validation Acc: 54.3
# Epoch: [6/10], Step: [501/3125], Validation Acc: 52.9
# Epoch: [6/10], Step: [601/3125], Validation Acc: 51.7
# Epoch: [6/10], Step: [701/3125], Validation Acc: 51.8
# Epoch: [6/10], Step: [801/3125], Validation Acc: 52.1
# Epoch: [6/10], Step: [901/3125], Validation Acc: 50.2
# Epoch: [6/10], Step: [1001/3125], Validation Acc: 54.6
# Epoch: [6/10], Step: [1101/3125], Validation Acc: 52.0
# Epoch: [6/10], Step: [1201/3125], Validation Acc: 52.9
# Epoch: [6/10], Step: [1301/3125], Validation Acc: 50.2
# Epoch: [6/10], Step: [1401/3125], Validation Acc: 52.6
# Epoch: [6/10], Step: [1501/3125], Validation Acc: 55.5
# Epoch: [6/10], Step: [1601/3125], Validation Acc: 56.5
# Epoch: [6/10], Step: [1701/3125], Validation Acc: 55.0
# Epoch: [6/10], Step: [1801/3125], Validation Acc: 52.2
# Epoch: [6/10], Step: [1901/3125], Validation Acc: 53.3
# Epoch: [6/10], Step: [2001/3125], Validation Acc: 50.5
# Epoch: [6/10], Step: [2101/3125], Validation Acc: 52.1
# Epoch: [6/10], Step: [2201/3125], Validation Acc: 52.7
# Epoch: [6/10], Step: [2301/3125], Validation Acc: 51.9
# Epoch: [6/10], Step: [2401/3125], Validation Acc: 54.5
# Epoch: [6/10], Step: [2501/3125], Validation Acc: 53.7
# Epoch: [6/10], Step: [2601/3125], Validation Acc: 52.9
# Epoch: [6/10], Step: [2701/3125], Validation Acc: 53.5
# Epoch: [6/10], Step: [2801/3125], Validation Acc: 53.8
# Epoch: [6/10], Step: [2901/3125], Validation Acc: 52.5
# Epoch: [6/10], Step: [3001/3125], Validation Acc: 51.6
# Epoch: [6/10], Step: [3101/3125], Validation Acc: 55.0
# Epoch: [7/10], Step: [101/3125], Validation Acc: 51.1
# Epoch: [7/10], Step: [201/3125], Validation Acc: 53.5
# Epoch: [7/10], Step: [301/3125], Validation Acc: 51.3
# Epoch: [7/10], Step: [401/3125], Validation Acc: 53.3
# Epoch: [7/10], Step: [501/3125], Validation Acc: 51.3
# Epoch: [7/10], Step: [601/3125], Validation Acc: 54.4
# Epoch: [7/10], Step: [701/3125], Validation Acc: 52.8
# Epoch: [7/10], Step: [801/3125], Validation Acc: 50.8
# Epoch: [7/10], Step: [901/3125], Validation Acc: 52.7
# Epoch: [7/10], Step: [1001/3125], Validation Acc: 55.5
# Epoch: [7/10], Step: [1101/3125], Validation Acc: 51.6
# Epoch: [7/10], Step: [1201/3125], Validation Acc: 53.0
# Epoch: [7/10], Step: [1301/3125], Validation Acc: 53.7
# Epoch: [7/10], Step: [1401/3125], Validation Acc: 53.1
# Epoch: [7/10], Step: [1501/3125], Validation Acc: 54.1
# Epoch: [7/10], Step: [1601/3125], Validation Acc: 52.7
# Epoch: [7/10], Step: [1701/3125], Validation Acc: 54.3
# Epoch: [7/10], Step: [1801/3125], Validation Acc: 53.8
# Epoch: [7/10], Step: [1901/3125], Validation Acc: 51.2
# Epoch: [7/10], Step: [2001/3125], Validation Acc: 52.8
# Epoch: [7/10], Step: [2101/3125], Validation Acc: 53.7
# Epoch: [7/10], Step: [2201/3125], Validation Acc: 52.0
# Epoch: [7/10], Step: [2301/3125], Validation Acc: 52.7
# Epoch: [7/10], Step: [2401/3125], Validation Acc: 52.3
# Epoch: [7/10], Step: [2501/3125], Validation Acc: 52.5
# Epoch: [7/10], Step: [2601/3125], Validation Acc: 52.1
# Epoch: [7/10], Step: [2701/3125], Validation Acc: 54.9
# Epoch: [7/10], Step: [2801/3125], Validation Acc: 56.3
# Epoch: [7/10], Step: [2901/3125], Validation Acc: 53.4
# Epoch: [7/10], Step: [3001/3125], Validation Acc: 55.0
# Epoch: [7/10], Step: [3101/3125], Validation Acc: 55.3
# Epoch: [8/10], Step: [101/3125], Validation Acc: 50.9
# Epoch: [8/10], Step: [201/3125], Validation Acc: 54.0
# Epoch: [8/10], Step: [301/3125], Validation Acc: 53.5
# Epoch: [8/10], Step: [401/3125], Validation Acc: 53.6
# Epoch: [8/10], Step: [501/3125], Validation Acc: 54.8
# Epoch: [8/10], Step: [601/3125], Validation Acc: 52.5
# Epoch: [8/10], Step: [701/3125], Validation Acc: 51.0
# Epoch: [8/10], Step: [801/3125], Validation Acc: 57.4
# Epoch: [8/10], Step: [901/3125], Validation Acc: 52.9
# Epoch: [8/10], Step: [1001/3125], Validation Acc: 52.8
# Epoch: [8/10], Step: [1101/3125], Validation Acc: 54.6
# Epoch: [8/10], Step: [1201/3125], Validation Acc: 53.9
# Epoch: [8/10], Step: [1301/3125], Validation Acc: 52.1
# Epoch: [8/10], Step: [1401/3125], Validation Acc: 53.9
# Epoch: [8/10], Step: [1501/3125], Validation Acc: 50.2
# Epoch: [8/10], Step: [1601/3125], Validation Acc: 54.2
# Epoch: [8/10], Step: [1701/3125], Validation Acc: 55.7
# Epoch: [8/10], Step: [1801/3125], Validation Acc: 52.5
# Epoch: [8/10], Step: [1901/3125], Validation Acc: 51.3
# Epoch: [8/10], Step: [2001/3125], Validation Acc: 50.3
# Epoch: [8/10], Step: [2101/3125], Validation Acc: 53.5
# Epoch: [8/10], Step: [2201/3125], Validation Acc: 52.6
# Epoch: [8/10], Step: [2301/3125], Validation Acc: 53.6
# Epoch: [8/10], Step: [2401/3125], Validation Acc: 53.0
# Epoch: [8/10], Step: [2501/3125], Validation Acc: 51.6
# Epoch: [8/10], Step: [2601/3125], Validation Acc: 53.2
# Epoch: [8/10], Step: [2701/3125], Validation Acc: 50.4
# Epoch: [8/10], Step: [2801/3125], Validation Acc: 54.0
# Epoch: [8/10], Step: [2901/3125], Validation Acc: 55.2
# Epoch: [8/10], Step: [3001/3125], Validation Acc: 53.8
# Epoch: [8/10], Step: [3101/3125], Validation Acc: 53.4
# Epoch: [9/10], Step: [101/3125], Validation Acc: 53.4
# Epoch: [9/10], Step: [201/3125], Validation Acc: 54.2
# Epoch: [9/10], Step: [301/3125], Validation Acc: 53.6
# Epoch: [9/10], Step: [401/3125], Validation Acc: 53.4
# Epoch: [9/10], Step: [501/3125], Validation Acc: 54.1
# Epoch: [9/10], Step: [601/3125], Validation Acc: 54.3
# Epoch: [9/10], Step: [701/3125], Validation Acc: 54.0
# Epoch: [9/10], Step: [801/3125], Validation Acc: 55.7
# Epoch: [9/10], Step: [901/3125], Validation Acc: 55.6
# Epoch: [9/10], Step: [1001/3125], Validation Acc: 53.1
# Epoch: [9/10], Step: [1101/3125], Validation Acc: 52.1
# Epoch: [9/10], Step: [1201/3125], Validation Acc: 53.5
# Epoch: [9/10], Step: [1301/3125], Validation Acc: 55.2
# Epoch: [9/10], Step: [1401/3125], Validation Acc: 57.7
# Epoch: [9/10], Step: [1501/3125], Validation Acc: 52.7
# Epoch: [9/10], Step: [1601/3125], Validation Acc: 55.0
# Epoch: [9/10], Step: [1701/3125], Validation Acc: 52.3
# Epoch: [9/10], Step: [1801/3125], Validation Acc: 52.4
# Epoch: [9/10], Step: [1901/3125], Validation Acc: 53.3
# Epoch: [9/10], Step: [2001/3125], Validation Acc: 52.9
# Epoch: [9/10], Step: [2101/3125], Validation Acc: 53.4
# Epoch: [9/10], Step: [2201/3125], Validation Acc: 52.0
# Epoch: [9/10], Step: [2301/3125], Validation Acc: 52.1
# Epoch: [9/10], Step: [2401/3125], Validation Acc: 54.1
# Epoch: [9/10], Step: [2501/3125], Validation Acc: 51.8
# Epoch: [9/10], Step: [2601/3125], Validation Acc: 51.6
# Epoch: [9/10], Step: [2701/3125], Validation Acc: 54.7
# Epoch: [9/10], Step: [2801/3125], Validation Acc: 53.4
# Epoch: [9/10], Step: [2901/3125], Validation Acc: 55.2
# Epoch: [9/10], Step: [3001/3125], Validation Acc: 52.0
# Epoch: [9/10], Step: [3101/3125], Validation Acc: 54.7
# Epoch: [10/10], Step: [101/3125], Validation Acc: 53.3
# Epoch: [10/10], Step: [201/3125], Validation Acc: 53.0
# Epoch: [10/10], Step: [301/3125], Validation Acc: 53.9
# Epoch: [10/10], Step: [401/3125], Validation Acc: 56.9
# Epoch: [10/10], Step: [501/3125], Validation Acc: 56.8
# Epoch: [10/10], Step: [601/3125], Validation Acc: 55.9
# Epoch: [10/10], Step: [701/3125], Validation Acc: 53.0
# Epoch: [10/10], Step: [801/3125], Validation Acc: 52.3
# Epoch: [10/10], Step: [901/3125], Validation Acc: 51.2
# Epoch: [10/10], Step: [1001/3125], Validation Acc: 52.9
# Epoch: [10/10], Step: [1101/3125], Validation Acc: 51.1
# Epoch: [10/10], Step: [1201/3125], Validation Acc: 52.5
# Epoch: [10/10], Step: [1301/3125], Validation Acc: 52.8
# Epoch: [10/10], Step: [1401/3125], Validation Acc: 52.0
# Epoch: [10/10], Step: [1501/3125], Validation Acc: 54.4
# Epoch: [10/10], Step: [1601/3125], Validation Acc: 53.4
# Epoch: [10/10], Step: [1701/3125], Validation Acc: 51.9
# Epoch: [10/10], Step: [1801/3125], Validation Acc: 53.4
# Epoch: [10/10], Step: [1901/3125], Validation Acc: 55.0
# Epoch: [10/10], Step: [2001/3125], Validation Acc: 53.5
# Epoch: [10/10], Step: [2101/3125], Validation Acc: 55.8
# Epoch: [10/10], Step: [2201/3125], Validation Acc: 57.5
# Epoch: [10/10], Step: [2301/3125], Validation Acc: 54.9
# Epoch: [10/10], Step: [2401/3125], Validation Acc: 53.9
# Epoch: [10/10], Step: [2501/3125], Validation Acc: 53.8
# Epoch: [10/10], Step: [2601/3125], Validation Acc: 52.9
# Epoch: [10/10], Step: [2701/3125], Validation Acc: 53.9
# Epoch: [10/10], Step: [2801/3125], Validation Acc: 55.2
# Epoch: [10/10], Step: [2901/3125], Validation Acc: 52.4
# Epoch: [10/10], Step: [3001/3125], Validation Acc: 51.2
# Epoch: [10/10], Step: [3101/3125], Validation Acc: 53.3

# %%
epa
# Out:
# [53.606451612903214,
#  53.56774193548387,
#  53.319354838709685,
#  53.309677419354834,
#  53.20967741935483,
#  52.93548387096775,
#  53.135483870967754,
#  53.10967741935484,
#  53.661290322580655,
#  53.67741935483872]

# %%
epl
# Out:
# [1.1213771643177155,
#  1.1042435515311457,
#  1.1063944678152762,
#  1.0960471630096436,
#  1.1129404383320962,
#  1.1130090144372755,
#  1.102239647219258,
#  1.1130671654978106,
#  1.1049958967393445,
#  1.1003511028905069]
